# %% [markdown]
# # Описание проекта:

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.

# %% [markdown]
# # Как решать задачу:

# %% [markdown]
# **1.** Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень»;
#
# **2.** Нужно собрать данные по клиентам по следующим группам:
# * Признаки, которые описывают коммуникацию сотрудников компании с клиентом;
# * Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто;
# * Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине;
# * Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# # Описание данных:

# %% [markdown]
# **1. df_market_file.csv** - таблица с данными о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# * **id** — номер покупателя в корпоративной базе данных;
# * **Покупательская активность** — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень»;
# * **Тип сервиса** — уровень сервиса, например «премиум» и «стандарт»;
# * **Разрешить сообщать** — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель;
# * **Маркет_актив_6_мес** — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента;
# * **Маркет_актив_тек_мес** — количество маркетинговых коммуникаций в текущем месяце;
# * **Длительность** — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте;
# * **Акционные_покупки** — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев;
# * **Популярная_категория** — самая популярная категория товаров у покупателя за последние 6 месяцев;
# * **Средний_просмотр_категорий_за_визит** — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца;
# * **Неоплаченные_продукты_штук_квартал** — общее число неоплаченных товаров в корзине за последние 3 месяца;
# * **Ошибка_сервиса** — число сбоев, которые коснулись покупателя во время посещения сайта;
# * **Страниц_за_визит** — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# **2. market_money.csv** - таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# * **id** — номер покупателя в корпоративной базе данных;
# * **Период** — название периода, во время которого зафиксирована выручка;
# * **Выручка** — сумма выручки за период.
#
# **3. market_time.csv** - таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# * **id** — номер покупателя в корпоративной базе данных;
# * **Период** — название периода, во время которого зафиксировано общее время;
# * **минут** — значение времени, проведённого на сайте, в минутах/
#
# **4. money.csv** - таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# * **id** — номер покупателя в корпоративной базе данных;
# * **Прибыль** — значение прибыли.

# %% [markdown]
# # Содержание:

# %% [markdown]
# [1. Загрузка данных](#chapter1)
# * [1.1 Импорт библиотек, моделей, метрик. Загрузка исходных датафреймов с данными](#chapter1)
# * [1.2 Общая информацию о каждом датафрейме](#chapter1.2)
#     * [1.2.1 Первый датафрейм: df_market_file](#chapter1.2)
#     * [1.2.2 Второй датафрейм: df_market_money](#chapter1.2.2)
#     * [1.2.3 Третий датафрейм: df_market_time](#chapter1.2.3)
#     * [1.2.4 Четвёртый датафрейм: df_money](#chapter1.2.4)

# %% [markdown]
# [2. Предобработка данных](#chapter2)
# * [2.1 Предобработка первого датафрейма: df_market_file](#chapter2)
# * [2.2 Предобработка второго датфрейма: df_market_money](#chapter2.2)
# * [2.3 Предобработка третьего датафрейма: df_market_time](#chapter2.3)
# * [2.4 Предобработка четвертого датафрейма: df_money](#chapter2.4)

# %% [markdown]
# [3. Исследовательский анализ данных](#chapter3)
# * [3.1 Исследовательский анализ первого датафрейма: df_market_file](#chapter3)
#     * [3.1.1 Количественные данные](#chapter3)
#     * [3.1.2 Категориальные данные](#chapter3.1.2)
# * [3.2 Исследовательский анализ второго датфрейма: df_market_money](#chapter3.2)
#     * [3.2.1 Количественные данные](#chapter3.2)
#     * [3.2.2 Категориальные данные](#chapter3.2.2)
# * [3.3 Исследовательский анализ третьего датафрейма: df_market_time](#chapter3.3)
#     * [3.3.1 Количественные данные](#chapter3.3)
#     * [3.3.2 Категориальные данные](#chapter3.3.2)
# * [3.4 Исследовательский анализ четвертого датафрейма: df_money](#chapter3.4)
#     * [3.4.1 Количественные данные](#chapter3.4.1)

# %% [markdown]
# [4. Объединение таблиц](#chapter4)

# %% [markdown]
# [5. Корреляционный анализ](#chapter5)

# %% [markdown]
# [6. Использование пайплайнов](#chapter6)
# * [6.1 Подготовка данных и создание пайплайна](#chapter6)
# * [6.2 Обучение 4 моделей: DecisionTreeClassifier(), KNeighborsClassifier(), LogisticRegression(), SVC()](#chapter6.2)
# * [6.3  Выбор лучшей модели](#chapter6.3)

# %% [markdown]
# [7. Анализ важности признаков](#chapter7)
# * [7.1 Оценка важности признаков и график важности с помощью метода SHAP](#chapter7)

# %% [markdown]
# [8. Сегментация покупателей](#chapter8)

# %% [markdown]
# [9. Общий вывод](#chapter9)

# %% [markdown]
# <a class="anchor" id="chapter1"></a>

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Импорт библиотек, моделей, метрик. Загрузка исходных датафреймов с данными.

# %%
# загрузка инсталяций:
# !pip install -U scikit-learn
# !pip install shap -q

# %%
#загрузка библиотек:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st
import shap

#загрузка модели/метрики:
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, recall_score, precision_score, roc_auc_score, f1_score
from sklearn.compose import ColumnTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer 
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import GridSearchCV

# %%
# загрузка исходных датафреймов с данными:
df_market_file = pd.read_csv('/datasets/market_file.csv')
df_market_money = pd.read_csv('/datasets/market_money.csv')
df_market_time = pd.read_csv('/datasets/market_time.csv')
df_money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# %% [markdown]
# <a class="anchor" id="chapter1.2"></a>

# %% [markdown]
# ### Общая информацию о каждом датафрейме.

# %% [markdown]
# #### Первый датафрейм: df_market_file

# %%
# предварительное ознакомление с первым датафреймом:
def main_info(df):
    s = df.sample(10)
    i = df.info()
    return s
    return i
main_info(df_market_file)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
df_market_file.describe()
# Out:
#                   id  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# ...

# %% [markdown]
# <a class="anchor" id="chapter1.2.2"></a>

# %% [markdown]
# ####  Второй датафрейм: df_market_money

# %%
# предварительное ознакомление со вторым датафреймом:
main_info(df_market_money)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
#           id               Период  Выручка
# 2249  216097  препредыдущий_месяц   4470.0
# 3157  216400  препредыдущий_месяц   4974.0
# 2494  216179  препредыдущий_месяц   5387.0
# 2985  216343  препредыдущий_месяц   4918.0
# 217   215420     предыдущий_месяц   5264.0
# 537   215527  препредыдущий_месяц   4472.0
# 478   215507  препредыдущий_месяц   4969.0
# 214   215419  препредыдущий_месяц   4756.0
# 2990  216344        текущий_месяц   6780.4
# 85    215376        текущий_месяц   6209.2

# %%
df_market_money.describe()
# Out:
#                   id        Выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %% [markdown]
# <a class="anchor" id="chapter1.2.3"></a>

# %% [markdown]
# ####  Третий датафрейм: df_market_time

# %%
# предварительное ознакомление с третьим датафреймом:
main_info(df_market_time)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
#           id            Период  минут
# 98    215397  предыдцщий_месяц      6
# 433   215564     текущий_месяц     12
# 710   215703  предыдцщий_месяц      8
# 2440  216568     текущий_месяц     19
# 1631  216163  предыдцщий_месяц     17
# 1062  215879     текущий_месяц     13
# 482   215589     текущий_месяц      4
# 2478  216587     текущий_месяц     17
# 2514  216605  предыдцщий_месяц     14
# 1513  216104     текущий_месяц     17

# %%
df_market_time.describe()
# Out:
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %% [markdown]
# <a class="anchor" id="chapter1.2.4"></a>

# %% [markdown]
# ####  Четвёртый датафрейм: df_money

# %%
# предварительное ознакомление с четвёртым датафреймом:
main_info(df_money)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
#           id  Прибыль
# 290   215638     4.94
# 950   216298     5.07
# 1259  216607     4.91
# 469   215817     2.43
# 964   216312     4.54
# 1026  216374     7.21
# 1293  216641     4.50
# 355   215703     2.86
# 955   216303     4.69
# 377   215725     5.06

# %%
df_money.describe()
# Out:
#                   id      Прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %% [markdown]
# **Вывод: На первый взгляд, информация в датафреймах выглядет корректной, наименования столбцов соответствуют содержанию. В датафрейме 'df_market_time' в столбце 'Период' присутствует орфографическая ошибка, которую в дальнейшем исправим. В датафрейме 'df_market_money' есть аномальное значение. Для определения пропущенных значений, явных/неявных дубликатов, и оформления информации в едином стиле требуется предобработка данных**

# %% [markdown]
# <a class="anchor" id="chapter2"></a>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Предобработка первого датафрейма: df_market_file

# %%
def preprocessing (df):
    first_stage = df.duplicated().sum()
    second_stage = df.drop_duplicates(inplace=True)
    third_stage = df.isna().sum()
    pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')
    print('Количество дубликатов:', first_stage)
    print('\n')
    print('Удаление дубликатов:', second_stage)
    print('\n')
    print('Итоговый подсчёт пропущенных значений:')
    return third_stage
preprocessing(df_market_file)
# Out:
# Количество дубликатов: 0
#
#
# Удаление дубликатов: None
#
#
# Итоговый подсчёт пропущенных значений:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# dtype: int64

# %%
# приводим столбцы к единому регистру и немного упрощаем обозначения столбцов:
df_market_file = df_market_file.rename(
    columns = {
        'Покупательская активность' : 'активность',
        'Тип сервиса' : 'сервис',
        'Разрешить сообщать' : 'сообщения',
        'Маркет_актив_6_мес' : 'активность_6мес',
        'Маркет_актив_тек_мес' : 'активность_текущая',
        'Длительность' : 'длительность',
        'Акционные_покупки' : 'акционные_покупки',
        'Популярная_категория' : 'категория',
        'Средний_просмотр_категорий_за_визит' : 'средний_просмотр_категорий_за_визит',
        'Неоплаченные_продукты_штук_квартал' : 'неоплаченные_продукты_квартал',
        'Ошибка_сервиса' : 'ошибки',
        'Страниц_за_визит' : 'страницы_за_визит',
    }
)

# %%
# приводим значения в столбцах к единому регистру:
df_market_file['активность'] = df_market_file['активность'].str.lower()
df_market_file['сервис'] = df_market_file['сервис'].str.lower()
df_market_file['сообщения'] = df_market_file['сообщения'].str.lower()
df_market_file['категория'] = df_market_file['категория'].str.lower()

# %%
# Проверяем столбцы с категориальными значения на скрытые дубликаты, исправляем если находим:
df_market_file['активность'].unique()
# Out:
# array(['снизилась', 'прежний уровень'], dtype=object)

# %%
df_market_file['сервис'].unique()
df_market_file = df_market_file.apply(lambda x: x.replace({'стандартт' : 'стандарт'}, regex=True))

# %%
df_market_file['сообщения'].unique()
# Out:
# array(['да', 'нет'], dtype=object)

# %%
df_market_file['категория'].unique()
# Out:
# array(['товары для детей', 'домашний текстиль', 'косметика и аксесуары',
#        'техника для красоты и здоровья', 'кухонная посуда',
#        'мелкая бытовая техника и электроника'], dtype=object)

# %%
df_market_file.sample(5)
# Out:
#           id       активность    сервис сообщения  активность_6мес  \
# 989   216337  прежний уровень  стандарт       нет              3.7
# 770   216118  прежний уровень  стандарт        да              3.6
# 252   215600        снизилась  стандарт        да              2.4
# 1042  216390  прежний уровень  стандарт        да              6.1
# 668   216016  прежний уровень  стандарт        да              4.1
#
#       активность_текущая  длительность  акционные_покупки  \
# 989                    3           638               0.13
# 770                    4           417               0.30
# 252                    4           446               0.29
# 1042                   5           876               0.17
# 668                    3           495               0.16
#
#                                  категория  \
# 989                      домашний текстиль
# 770                       товары для детей
# 252                        кухонная посуда
# ...

# %% [markdown]
# **Вывод: явных дубликатов нет, пропущенных значений нет. Значения в категориальных столбцах приведены к нижнему регистру для профилактики неявных дублей. Названия столбцов также приведены к нижнему регистру и сокращены без потери по смыслу. Исправлены неявные дубликаты/опечатки в строках.**

# %% [markdown]
# <a class="anchor" id="chapter2.2"></a>

# %% [markdown]
# ### Предобработка второго датфрейма: df_market_money

# %%
# активируем функцию:
preprocessing(df_market_money)
# Out:
# Количество дубликатов: 0
#
#
# Удаление дубликатов: None
#
#
# Итоговый подсчёт пропущенных значений:
# id         0
# Период     0
# Выручка    0
# dtype: int64

# %%
# приводим столбцы к единому регистру:
df_market_money = df_market_money.rename(
    columns = {
        'Период' : 'период',
        'Выручка' : 'выручка',
    }
)

# %%
df_market_money['период'] = df_market_money['период'].str.lower()

# %%
df_market_money['период'].unique()
df_market_money = df_market_money.apply(lambda x: x.replace({'текущий_месяц':'текущий месяц', 'предыдущий_месяц': 'предыдущий месяц'}, regex=True))

# %%
df_market_money.sample(5)
# Out:
#           id               период  выручка
# 1656  215900  препредыдущий месяц   5241.0
# 1909  215984     предыдущий месяц   5529.5
# 2751  216265        текущий месяц   6991.2
# 3826  216623        текущий месяц   5840.3
# 817   215620        текущий месяц   5247.2

# %% [markdown]
# **Вывод: явных дубликатов нет, пропущенных значений нет. Значения в категориальных столбцах приведены к нижнему регистру для профилактики неявных дублей. Названия столбцов также приведены к нижнему регистру.**

# %% [markdown]
# <a class="anchor" id="chapter2.3"></a>

# %% [markdown]
# ### Предобработка третьего датафрейма: df_market_time

# %%
# активируем функцию:
preprocessing(df_market_time)
# Out:
# Количество дубликатов: 0
#
#
# Удаление дубликатов: None
#
#
# Итоговый подсчёт пропущенных значений:
# id        0
# Период    0
# минут     0
# dtype: int64

# %%
df_market_time = df_market_time.rename(
    columns = {
        'Период' : 'период',
    }
)

# %%
df_market_time['период'] = df_market_time['период'].str.lower()

# %%
df_market_time['период'].unique()
df_market_time = df_market_time.apply(lambda x: x.replace({'предыдцщий_месяц' : 'предыдущий месяц', 'текущий_месяц':'текущий месяц'}, regex=True))

# %%
df_market_time.sample(5)
# Out:
#           id            период  минут
# 283   215489  предыдущий месяц      9
# 1918  216307  предыдущий месяц     20
# 945   215820  предыдущий месяц     18
# 1000  215848     текущий месяц     11
# 2448  216572  предыдущий месяц     11

# %% [markdown]
# **Вывод: явных дубликатов нет, пропущенных значений нет. Значения в столбцах приведены к нижнему регистру для профилактики неявных дублей. Названия столбцов также приведены к нижнему регистру. Исправлены неявные дубликаты/опечатки в строках.**

# %% [markdown]
# <a class="anchor" id="chapter2.4"></a>

# %% [markdown]
# ### Предобработка четвертого датафрейма: df_money

# %%
# активируем функцию:
preprocessing(df_money)
# Out:
# Количество дубликатов: 0
#
#
# Удаление дубликатов: None
#
#
# Итоговый подсчёт пропущенных значений:
# id         0
# Прибыль    0
# dtype: int64

# %%
df_money = df_money.rename(
    columns = {
        'Прибыль' : 'прибыль',
    }
)

# %%
df_money.sample(5)
# Out:
#           id  прибыль
# 300   215648     4.28
# 129   215477     3.66
# 1067  216415     3.56
# 571   215919     4.62
# 260   215608     5.35

# %% [markdown]
# **Вывод: в датафреймах не обнаружено явных дубликатов и пропущенных значений. Категориальные значения приведены к нижнему регистру для профилактики неявных дублей. Столбцы приведены к единому стилю, сделаны исправления орфографическик ошибок.**

# %% [markdown]
# <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследовательский анализ первого датафрейма: df_market_file

# %% [markdown]
# #### Количественные данные

# %%
def hist (data, column):
    plt.figure(figsize=(13,4))
    plt.subplot(1,2,1)
    plt.xlabel(f'Значения {column}')
    plt.ylabel('Количество')
    plt.title(f'Гистограмма {column}')
    sns.histplot(data=data, x=column, hue='активность', kde=True)
    plt.subplot(1,2,2)
    plt.xlabel(f'Значения {column}')
    plt.title(f'Диаграмма размаха {column}')
    sns.boxplot(x=data[column], color='LightGrey')

# %%
# формируем список количественных столбцов фатафрейма df_market_file:
numerical_market_file =[
    'активность_6мес',
    'активность_текущая',
    'длительность',
    'акционные_покупки',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_квартал',
    'ошибки',
    'страницы_за_визит' 
]

# %%
# активируем функцию:
for row in numerical_market_file:
    hist(df_market_file, row)

# %%
df_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   активность                           1300 non-null   object
#  2   сервис                               1300 non-null   object
#  3   сообщения                            1300 non-null   object
#  4   активность_6мес                      1300 non-null   float64
#  5   активность_текущая                   1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   категория                            1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_квартал        1300 non-null   int64
# ...

# %%
df_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   активность                           1300 non-null   object
#  2   сервис                               1300 non-null   object
#  3   сообщения                            1300 non-null   object
#  4   активность_6мес                      1300 non-null   float64
#  5   активность_текущая                   1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   категория                            1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_квартал        1300 non-null   int64
# ...

# %%
df_market_file.boxplot(column=['активность_6мес'], figsize=(7, 4), grid=True)
plt.title('Диаграмма размаха')
plt.show()

# %% [markdown]
# **Вывод: Есть нормальные распределения, распределения со смещением, аномальные значения. Например товары по акциям не очень мотивируют пользователей на покупку, но при этом часть клиентов отслеживает скидки.**

# %% [markdown]
# <a class="anchor" id="chapter3.1.2"></a>

# %% [markdown]
# #### Категориальные данные

# %%
def pie_categorical(data, column, i, l, n):
    plt.figure(figsize=(30,15))
    plt.subplot(2, l, n)
    plt.title(f'Круговая диаграмма: {column}')
    plt.pie(x=data.groupby(column)[row].count(),
           startangle=150,
           labeldistance=1.1,
           wedgeprops = {'linewidth':2, 'edgecolor':'black'},
           autopct = '%.0f%%',
           labels = data.groupby(column)[row].count().index,
           colors = sns.color_palette('Set2')[0:10])

# %%
# формируем список категориальных столбцов фатафрейма df_market_file:
categorical_market_file = [
    'активность',
    'сервис',
    'сообщения',
    'категория'
]

# %%
# активируем функцию:
n = 1
plt.figure(figsize=(13,4))
for row in categorical_market_file:
    pie_categorical(df_market_file, row, 'id', len(categorical_market_file), n)
    n += 1

# %% [markdown]
# **Вывод: Круговые диаграммы категориальных признаков показывают:**
# * активность у более 60% покупателей осталась на прежнем уровне, у 34% снизилась;
# * более 2/3 пользователей пользуются стандартным уровнем сервиса;
# * также более 2/3 пользоателей согласны на рассылку сообщений;
# * наиболее популярные категории товаров - товары для детей, домашний текстиль и косметика/аксессуары.

# %% [markdown]
# <a class="anchor" id="chapter3.2"></a>

# %% [markdown]
# ### Исследовательский анализ второго датафрейма: df_market_money

# %% [markdown]
# #### Количественные данные

# %%
# формируем список количественных столбцов фатафрейма df_market_money:
numerical_market_money = ['выручка']

# %%
def hist (data, column):
    plt.figure(figsize=(13,4))
    plt.subplot(1,2,1)
    plt.xlabel(f'Значения {column}')
    plt.ylabel('Количество')
    plt.title(f'Гистограмма {column}')
    sns.histplot(data[column], color='DarkTurquoise', kde=True)
    plt.subplot(1,2,2)
    plt.xlabel(f'Значения {column}')
    plt.title(f'Диаграмма размаха {column}')
    sns.boxplot(x=data[column], color='LightGrey')

# %%
# активируем функцию:
for row in numerical_market_money:
    hist(df_market_money, row)

# %%
df_market_money.describe()
# Out:
#                   id        выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %% [markdown]
# **Вывод:Есть аномальное значение по выручке - 106862,2. Для улучшения качества данных, найдём и удалим это значение.**

# %%
# находим аномальное значение:
df_market_money[df_market_money['выручка'] == 106862.200000]
# Out:
#         id         период   выручка
# 98  215380  текущий месяц  106862.2

# %%
# удаляем строку:
df_market_money = df_market_money.drop(index=[98])

# %%
# обновляем индексы:
df_market_money = df_market_money.reset_index(drop=True)

# %%
df_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3899 entries, 0 to 3898
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3899 non-null   int64
#  1   период   3899 non-null   object
#  2   выручка  3899 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
for row in numerical_market_money:
    hist(df_market_money, row)

# %% [markdown]
# **Вывод: Распределение нормальное, оставляем как есть.**

# %% [markdown]
# <a class="anchor" id="chapter3.2.2"></a>

# %% [markdown]
# #### Категориальные данные

# %%
# формируем список категориальных столбцов фатафрейма df_market_money:
categorical_market_money = ['период']

# %%
# активируем функцию:
n = 1
plt.figure(figsize=(13,4))
for row in categorical_market_money:
    pie_categorical(df_market_money, row, 'id', len(categorical_market_money), n)
    n += 1

# %% [markdown]
# **Вывод: Распределение выручки по периодам равнозначное**

# %% [markdown]
# <a class="anchor" id="chapter3.3"></a>

# %% [markdown]
# ### Исследовательский анализ третьего датафрейма: df_market_time

# %% [markdown]
# #### Количественные данные

# %%
# формируем список количественных столбцов фатафрейма df_market_time:
numerical_market_time = ['минут']

# %%
# активируем функцию:
for row in numerical_market_time:
    hist(df_market_time, row)

# %% [markdown]
# **Вывод: Распределение по значению времени проведенного на сайте нормальное**

# %% [markdown]
# <a class="anchor" id="chapter3.3.2"></a>

# %% [markdown]
# #### Категориальные данные

# %%
# формируем список категориальных столбцов фатафрейма df_market_money:
categorical_market_time = ['период']

# %%
# активируем функцию:
n = 1
plt.figure(figsize=(13,4))
for row in categorical_market_time:
    pie_categorical(df_market_time, row, 'id', len(categorical_market_time), n)
    n += 1

# %% [markdown]
# **Вывод: Распределение периода во время которого зафиксировано общее время равнозначное**

# %% [markdown]
# <a class="anchor" id="chapter3.4"></a>

# %% [markdown]
# ### Исследовательский анализ четвертого датафрейма: df_money

# %%
df_money.sample(5)
# Out:
#           id  прибыль
# 813   216161     4.69
# 1008  216356     3.26
# 106   215454     3.81
# 235   215583     4.95
# 209   215557     5.44

# %% [markdown]
# <a class="anchor" id="chapter3.4.1"></a>

# %% [markdown]
# #### Количественные данные

# %%
# формируем список количественных столбцов фатафрейма df_money:
numerical_df_money = ['прибыль']

# %%
# активируем функцию:
for row in numerical_df_money:
    hist(df_money, row)

# %% [markdown]
# **Вывод: Распределение по прибыли нормальное**

# %%
df_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3899 entries, 0 to 3898
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3899 non-null   int64
#  1   период   3899 non-null   object
#  2   выручка  3899 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
df_market_money[df_market_money['выручка'] == 0]
# Out:
#         id               период  выручка
# 0   215348  препредыдущий месяц      0.0
# 2   215348     предыдущий месяц      0.0
# 28  215357  препредыдущий месяц      0.0
# 29  215357     предыдущий месяц      0.0
# 34  215359     предыдущий месяц      0.0
# 35  215359  препредыдущий месяц      0.0

# %%
df_market_money = df_market_money[df_market_money['выручка'] > 0]

# %%
df_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3893 entries, 1 to 3898
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3893 non-null   int64
#  1   период   3893 non-null   object
#  2   выручка  3893 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.7+ KB

# %% [markdown]
# <a class="anchor" id="chapter4"></a>

# %% [markdown]
# ## Объединение таблиц

# %%
#заготовка по новым столбцам:
periods_money = [
    'выручка_текущий_месяц',
    'выручка_предыдущий_месяц',
    'выручка_препредыдущий_месяц'
]

#ещё одна заготовка по новым столбцам:
periods_time = [
    'минут_текущий_месяц',
    'минут_предыдущий_месяц'
]

# подготовка df_market_money и df_market_time к объединению с df_market_file
df_market_money_new = df_market_money.pivot_table(index=['id'], columns=['период'])
df_market_money_new.columns = periods_money
df_market_money_new['id'] = df_market_money_new.index

df_market_time_new = df_market_time.pivot_table(index=['id'], columns=['период'])
df_market_time_new.columns = periods_time
df_market_time_new['id'] = df_market_time_new.index

# объединение и формирование нового датафрейма market_main:
market_main = df_market_file.join(df_market_money_new, on='id', lsuffix='_left', rsuffix='_выручка')
market_main = market_main.rename(columns={'id_left':'id'})
market_main = market_main.join(df_market_time_new, on='id', lsuffix='_left', rsuffix='_минут')
market_main = market_main.rename(columns={'id_left':'id'})
market_main = market_main.drop(['id_выручка', 'id_минут'], axis=1)

market_main = market_main.merge(df_money, on='id', how='left')

# %%
market_main.sample(5)
# Out:
#           id       активность    сервис сообщения  активность_6мес  \
# 1148  216496  прежний уровень  стандарт        да              4.7
# 98    215446        снизилась  стандарт        да              3.5
# 977   216325  прежний уровень  стандарт        да              2.6
# 832   216180  прежний уровень   премиум       нет              6.6
# 1030  216378  прежний уровень   премиум        да              5.7
#
#       активность_текущая  длительность  акционные_покупки  \
# 1148                   4           509               0.28
# 98                     4           788               0.32
# 977                    3           864               0.14
# 832                    4           887               0.25
# 1030                   3           636               0.14
#
#                                  категория  \
# 1148                 косметика и аксесуары
# 98          техника для красоты и здоровья
# 977                      домашний текстиль
# ...

# %%
main_info(market_main)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1299
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   активность                           1300 non-null   object
#  2   сервис                               1300 non-null   object
#  3   сообщения                            1300 non-null   object
#  4   активность_6мес                      1300 non-null   float64
#  5   активность_текущая                   1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   категория                            1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_квартал        1300 non-null   int64
# ...

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Так я же дропнул этого клиента на этапе ИАД .
# </div>

# %%
market_main.isna().sum().sum()
# Out:
# 7

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Удалил. А как он попал в общую таблицу? Я же объединял общую таблицу с таблицей df_market_money где его уже не было.
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 4: </b></font>\
# <font color='blue'> В df_market_file строчки с этими id остались, в итоге при объединении, появились пропуски.\
# В рабочих проектах датасеты обычно собираются из нескольких таблиц базы данных и это самая частая причина значений NaN в данных.</font>

# %% [markdown]
# <a class="anchor" id="chapter5"></a>

# %% [markdown]
# ## Корреляционный анализ

# %%
# построим матрицу:
corr = sns.heatmap(market_main.corr(method='spearman'), annot=True, fmt='.1f', cmap= 'bwr')

# %% [markdown]
# **Вывод: Есть сильная линейная взаимосвязь между входными признаками 'выручка_текущий_месяц' и 'выручка_препредыдущий_месяц'**

# %%
# пробуем убрать зависимость объединением 2 признаков в новый, и удалением старых признаков:
market_main['выручка_текущий_препредыдущий'] = market_main['выручка_текущий_месяц'] + market_main['выручка_препредыдущий_месяц']

# %%
market_main = market_main.drop('выручка_текущий_месяц', 1)
market_main = market_main.drop('выручка_препредыдущий_месяц', 1)

# %%
corr = sns.heatmap(market_main.corr(method='spearman'), annot=True, fmt='.1f', cmap= 'bwr')

# %% [markdown]
# **Вывод: Зависимость победили**

# %%
pd.DataFrame(round(market_main.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_9b1e7_row0_col0,#T_9b1e7_row1_col0,#T_9b1e7_row2_col0,#T_9b1e7_row3_col0,#T_9b1e7_row4_col0,#T_9b1e7_row5_col0,#T_9b1e7_row6_col0,#T_9b1e7_row7_col0,#T_9b1e7_row8_col0,#T_9b1e7_row9_col0,#T_9b1e7_row10_col0,#T_9b1e7_row11_col0,#T_9b1e7_row12_col0,#T_9b1e7_row14_col0,#T_9b1e7_row15_col0,#T_9b1e7_row16_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9b1e7_row13_col0{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_9b1e7_row17_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9b1e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b1e7_level0_row0" class="row_heading level0 row0" >id</th>
# ...

# %%
market_main = market_main.dropna(subset=['выручка_предыдущий_месяц', 'выручка_текущий_препредыдущий'])

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Сделал.
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 4: </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
pd.DataFrame(round(market_main.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_60578_row0_col0,#T_60578_row1_col0,#T_60578_row2_col0,#T_60578_row3_col0,#T_60578_row4_col0,#T_60578_row5_col0,#T_60578_row6_col0,#T_60578_row7_col0,#T_60578_row8_col0,#T_60578_row9_col0,#T_60578_row10_col0,#T_60578_row11_col0,#T_60578_row12_col0,#T_60578_row13_col0,#T_60578_row14_col0,#T_60578_row15_col0,#T_60578_row16_col0,#T_60578_row17_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_60578_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60578_level0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_60578_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_60578_level0_row1" class="row_heading level0 row1" >активность</th>
# ...

# %%
market_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 1 to 1299
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   активность                           1296 non-null   object
#  2   сервис                               1296 non-null   object
#  3   сообщения                            1296 non-null   object
#  4   активность_6мес                      1296 non-null   float64
#  5   активность_текущая                   1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   категория                            1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_квартал        1296 non-null   int64
# ...

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# ### Подготовка данных и создание пайплайна

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

#разбиваем данные из датафрейма на тренировочную и тестовые выборки:
X_train, X_test, y_train, y_test = train_test_split(
    market_main.drop(['активность', 'id'], axis=1),
    market_main['активность'],
    test_size = TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify = market_main['активность']
)

# создаём числовые и категориальные списки:
ohe_columns = [ 
    'сообщения', 
    'категория' 
]

num_columns = [
    'активность_6мес',
    'активность_текущая',
    'длительность',
    'акционные_покупки',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_квартал',
    'ошибки',
    'страницы_за_визит',
    'выручка_предыдущий_месяц',
    'минут_текущий_месяц',
    'минут_предыдущий_месяц',
    'выручка_текущий_препредыдущий',
    'прибыль'
]

ord_columns = [
    'сервис'
]

# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование:
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

ord_pipe = Pipeline(
    [
        (
            'simple_imputer_ord_before',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(categories=[
                                      ['стандарт','премиум']],
                          handle_unknown='use_encoded_value',
                          unknown_value=np.nan)
        ),
        (
            'simple_imputer_ord_after',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# создаём общий пайплайн для подготовки данных:
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('num', MinMaxScaler(), num_columns),
     ('ord', ord_pipe, ord_columns)
    ] 
)

# создаём итоговый пайплайн: подготовка данных и моделей:
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
]) 

param_grid = [
    # словарь для модели DecisionTreeClassifier():
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    },
    
    # словарь для модели KNeighborsClassifier(): 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]   
    },

    # словарь для модели LogisticRegression():
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'  
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    },
    
    # словарь для модели SVC():
    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='poly', probability= True)],
        'models__degree': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    }
]

# %% [markdown]
# <a class="anchor" id="chapter6.2"></a>

# %% [markdown]
# ### Обучение 4 моделей: DecisionTreeClassifier(), KNeighborsClassifier(), LogisticRegression(), SVC()

# %%
pd.options.mode.chained_assignment = None
#поиск лучшей модели без перебора гиперпараметров:
grid_model = GridSearchCV(
    pipe_final, 
    param_grid=param_grid,
    cv=5, 
    scoring='roc_auc',  
    n_jobs=-1
)
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          ['сообщения',
# ...

# %%
#поиск лучшей модели c перебором гиперпараметров:
randomized_model = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_model.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
# ...

# %% [markdown]
# <a class="anchor" id="chapter6.3"></a>

# %% [markdown]
# ### Выбор лучшей модели

# %%
print('Лучшая модель и её параметры:\n', grid_model.best_params_)
print('\n')
print('Метрика ROC-AUC для лучшей модели:\n', round(grid_model.best_score_, 3))
# Out:
# Лучшая модель и её параметры:
#  {'models': LogisticRegression(penalty='l1', random_state=42, solver='liblinear'), 'models__C': 1, 'preprocessor__num': MinMaxScaler()}
#
#
# Метрика ROC-AUC для лучшей модели:
#  0.898

# %%
print('Лучшая модель и её параметры:\n', randomized_model.best_params_) 
print('\n')
print('Метрика ROC-AUC для лучшей модели:\n', round(randomized_model.best_score_, 3))
# Out:
# Лучшая модель и её параметры:
#  {'preprocessor__num': MinMaxScaler(), 'models__C': 2, 'models': LogisticRegression(penalty='l1', random_state=42, solver='liblinear')}
#
#
# Метрика ROC-AUC для лучшей модели:
#  0.897

# %%
y_test_predict = grid_model.predict(X_test)
y_proba_predict = grid_model.predict_proba(X_test)

print(f'Метрика F1-score на тестовой выборке: {round(f1_score(y_test, y_test_predict, average="macro"), 3)}')
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test, y_proba_predict[:,1]), 3)}')
# Out:
# Метрика F1-score на тестовой выборке: 0.902
# Метрика ROC-AUC на тестовой выборке: 0.919

# %% [markdown]
# **Вывод: Примерно одинаковое качество предсказаний показали модели опорных векторов и логистической регрессии С. У данных моделей вероятность корректного предсказания 89,8% и 89,7% соответственно**

# %% [markdown]
# <a class="anchor" id="chapter7"></a>

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# ### Оценка важности признаков и  график важности с помощью метода SHAP

# %%
values = grid_model.best_estimator_['preprocessor'].fit_transform(X_train)
best_model = grid_model.best_estimator_['models'].fit(values, y_train)
explainer = shap.PermutationExplainer(best_model, values)
name = grid_model.best_estimator_[: -1].get_feature_names_out()
 
shap.summary_plot(
    values, 
    plot_type='bar',
    feature_names=name, 
    plot_size='auto')

shap.summary_plot(
    values, 
    plot_type='violin', 
    feature_names=name, 
    plot_size='auto')

# %% [markdown]
# **Вывод: Числовые признаки сильнее всего влияют на целевой показатель, категориальные признаки мало значимы для модели. Можно провести сегментацию покупателей по числовым данным**

# %% [markdown]
# <a class="anchor" id="chapter8"></a>

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# **Для исследования возьму группу  клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности. Так как сам отношу себя к этой группе.**

# %%
y_test_proba = grid_model.predict_proba(X_test)[:,1]
y_train_proba = grid_model.predict_proba(X_train)[:,1]

X_test_final = X_test.copy()
X_train_final = X_train.copy()
X_test_final['вероятность_снижения_активности'] = y_test_proba
X_train_final['вероятность_снижения_активности'] = y_train_proba
df_final = pd.concat([X_train_final, X_test_final])

# %%
numerical_values = [
    'активность_6мес',
    'активность_текущая',
    'длительность',
    'акционные_покупки',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_квартал',
    'ошибки',
    'страницы_за_визит',
    'выручка_предыдущий_месяц',
    'минут_текущий_месяц',
    'минут_предыдущий_месяц',
    'выручка_текущий_препредыдущий',
    'вероятность_снижения_активности',
    'прибыль'
]

# %%
df_final.sample(5)
# Out:
#         сервис сообщения  активность_6мес  активность_текущая  длительность  \
# 562   стандарт       нет              3.9                   3           509
# 411    премиум        да              3.6                   5           589
# 755   стандарт       нет              5.7                   4           528
# 1291  стандарт        да              4.8                   4           306
# 41     премиум        да              4.1                   3          1047
#
#       акционные_покупки                             категория  \
# 562                0.95                 косметика и аксесуары
# 411                0.21                       кухонная посуда
# 755                0.17  мелкая бытовая техника и электроника
# 1291               0.29                      товары для детей
# 41                 0.93                      товары для детей
#
#       средний_просмотр_категорий_за_визит  неоплаченные_продукты_квартал  \
# ...

# %%
# построим диаграммы рассеивания для числовых признаков:
for row in numerical_values:
    plt.figure(figsize=(10,8))
    plt.title(f'Диаграмма рассеяния: {row}', fontsize=18)
    plt.xlabel('Вероятность снижения активности', fontsize=14)
    plt.ylabel('Значения', fontsize=14)
    
    sns.scatterplot(
                data=df_final,
                x=df_final['вероятность_снижения_активности'],
                y=df_final[row],
                hue=row,
    )

# %% [markdown]
# ### **Вывод: Пороги значений для разделения покупателей на сегмент "Покупательская активность снизилась":**
# * активность в текущем месяце и за 6 месяцев **менее 3,5**;
# * акционные покупки  **менее 0,6**;
# * просмотриваемые страницы за визит **менее 3**;
# * неоплаченные заказы за квартал **более 6**;
# * выручка за предыдущий месяц **менее 4500**;
# * сумма выручки за текущий и предыдущие месяца **менее 8000**;
# * кол-во проведенных минут за текущий месяц **менее 9**;
# * кол-во проведенных минут за предыдущий месяц **менее 9**;
# * значение прибыли **менее 3**.
#
# **Распределение по акционным покупкам показывает что клиенты которые покупают по товар по акции имеют высокую вероятность перейти в статус "Покупательская активность снизилась". Рассмотрим группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.**

# %%
# добавляем в датафрейм новый столбец по сегментации:
df_final['тип_акционных_покупок'] = df_final['акционные_покупки']\
.apply( lambda x: 'частые покупки' if x>= 0.6 else 'редкие покупки' )

# %%
# добавляем в датафрейм новый столбец по сегментации группы клиентов 
# с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности:
df_final['сегмент'] = df_final\
.apply( lambda row: 'исследуемый сегмент' \
        if row['вероятность_снижения_активности'] > 0.7 and row['прибыль'] < 3 \
        else 'другой сегмент' \
      , axis=1)

# %%
df_final.head(5)
# Out:
#         сервис сообщения  активность_6мес  активность_текущая  длительность  \
# 510   стандарт        да              5.5                   4           510
# 13    стандарт        да              5.1                   4           199
# 536   стандарт        да              4.3                   5           997
# 1216  стандарт        да              5.6                   4           342
# 367    премиум        да              3.6                   5           873
#
#       акционные_покупки                             категория  \
# 510                0.15  мелкая бытовая техника и электроника
# 13                 0.23        техника для красоты и здоровья
# 536                0.17  мелкая бытовая техника и электроника
# 1216               0.94                       кухонная посуда
# 367                0.39                      товары для детей
#
#       средний_просмотр_категорий_за_визит  неоплаченные_продукты_квартал  \
# ...

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='прибыль', label='исследуемый сегмент', color='blue')
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='прибыль', label='другой сегмент', color='purple')
plt.legend()
plt.axvline(x=0.7, color='green', linestyle='--')
plt.axhline(y=3, color='green', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='акционные_покупки', label='исследуемый сегмент', color='blue')
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='акционные_покупки', label='другой сегмент', color='purple')
plt.legend()
plt.axvline(x=0.7, color='green', linestyle='--')
plt.axhline(y=0.6, color='green', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='активность_6мес', label='исследуемый сегмент', color='blue')
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='активность_6мес', label='другой сегмент', color='purple')
plt.legend()
plt.axvline(x=0.7, color='green', linestyle='--')
plt.axhline(y=3, color='green', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='страницы_за_визит', label='исследуемый сегмент', color='blue')
sns.scatterplot(data=df_final, x='вероятность_снижения_активности', y='страницы_за_визит', label='другой сегмент', color='purple')
plt.legend()
plt.axvline(x=0.7, color='green', linestyle='--')
plt.axhline(y=3.5, color='green', linestyle='--')
plt.show()

# %%
categorical_values = [
    'сервис',
    'сообщения',
    'категория',
    'тип_акционных_покупок',
    'сегмент'
]

# %%
def categorical (data, column):
    plt.figure(figsize=(10,4))
    plot = sns.countplot(y=column, data=data)
    plot.set_title(f'Рапределение по {column}', fontsize=18)
    plot.set_xlabel('Количество', fontsize=14)

# %%
# активируем функцию:
for row in categorical_values:
    categorical (df_final, row)

# %%
numerical_values1 = [
    'активность_6мес',
    'активность_текущая',
    'длительность',
    'акционные_покупки',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_квартал',
    'страницы_за_визит',
    'выручка_предыдущий_месяц',
    'минут_текущий_месяц',
    'минут_предыдущий_месяц',
    'выручка_текущий_препредыдущий',
    'прибыль'
]

# %%
def hist1 (data, column, target):
    plt.figure(figsize=(10,4))
    plot = sns.histplot(data, kde=True, hue=target, x=column, stat='density', common_norm=False)

# %%
for row in numerical_values1:
    hist1 (df_final, row, 'сегмент')

# %% [markdown]
# <a class="anchor" id="chapter9"></a>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для выполнения проекта были предоставлены 4 датасета с данными клиентов интернет магазина "В один клик"

# %% [markdown]
# **Изучение данных:** В ходе ознакомления с данными перед дальнейшими исследованиями были реализованы следующие шаги:
# - Изучена  общая информация по 4-м датафреймам: **df_market_file** с данными о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении; **df_market_money** с данными о выручке, которую получает магазин с покупателя; **df_market_time** с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода; **df_money** с данными о среднемесячной прибыли покупателя за последние 3 месяца/
# - Выявлено, что информация в датафреймах корректна, содержание соответствует наименованиям столбцов;
# - Скорректирован дальнейший план действий по предобработке данных.

# %% [markdown]
# **Предобработка данных:**
#
# **df_market_file:**
# - В датафрейме не выявлено явных дубликатов;
# - Проанализированы уникальные значения в столбцах с категориальными данными;
# - Данные в категориальных столбцах  приведены к нижнему регистру для профилактики появления неявных дублей;
# - Пропущенных значений нет;
# - Столбцы приведены к единому стилю, исправлены неявные дубликаты/опечатки в строках.
#
# **df_market_money:**
# - Явных дубликатов нет;
# - Пропущенных значений нет;
# - Данные в категориальных столбцах  приведены к нижнему регистру для профилактики появления неявных дублей.
#
# **df_market_time:**
# - Явных дубликатов нет;
# - Пропущенных значений нет;
# - Значения в столбцах приведены к нижнему регистру для профилактики неявных дублей;
# - Названия столбцов также приведены к нижнему регистру;
# - Исправлены неявные дубликаты/опечатки в строках.
#
# **df_money:**
# - Явных дубликатов нет;
# - Пропущенных значений нет;
# - Категориальные значения приведены к нижнему регистру для профилактики неявных дублей;
# - Столбцы приведены к единому стилю, сделаны исправления орфографическик ошибок.

# %% [markdown]
# **Исследовательский анализ:**
#
# **df_market_file:**
# - Есть нормальные распределения, распределения со смещением, аномальные значения. Например товары по акциям не очень мотивируют пользователей на покупку, но при этом часть клиентов отслеживает скидки;
# - Круговые диаграммы категориальных признаков показывают:
# * активность у более 60% покупателей осталась на прежнем уровне, у 34% снизилась;
# * более 2/3 пользователей пользуются стандартным уровнем сервиса;
# * также более 2/3 пользоателей согласны на рассылку сообщений;
# * наиболее популярные категории товаров - товары для детей, домашний текстиль и косметика/аксессуары.
#
# **df_market_money:**
# - Было аномальное значение по выручке - 106862,2. Для улучшения качества, данное значение было удалено, распределение стало равномерным;
# - Распределение выручки по периодам равнозначное, по 33%.
#
# **df_market_time:**
# - Распределение по значению времени проведенного на сайте нормальное;
# - Распределение периода во время которого зафиксировано общее время равнозначное 50/50.
#
# **df_money:**
# - Распределение по прибыли нормальное.

# %% [markdown]
# **Корреляционный анализ:**
# - Была сильная линейная зависимость между входными признаками 'выручка_текущий_месяц' и 'выручка_препредыдущий_месяц'. Объединили 2 зависимых признаков в новый, и удалением старых признаков.

# %% [markdown]
# **Обучение 4 моделей: DecisionTreeClassifier(), KNeighborsClassifier(), LogisticRegression(), SVC():**
# - Был использован паплайн, количественные и категориальные признаки обработаны в пайплайне раздельно;
# - Для кодирования категориальных признаков использованы кодировщики SimpleImputer и OneHotEncoder, для масштабирования количественных — StandartScaler и MinMaxScaler.
# - Примерно одинаковое качество предсказаний показали модели опорных векторов и логистической регрессии С. У данных моделей вероятность корректного предсказания 89% и 88% соответственно/

# %% [markdown]
# **Анализ важности признаков:**
# - Числовые признаки сильнее всего влияют на целевой показатель модели, категориальные признаки мало значимы для модели. Можно провести сегментацию покупателей по числовым данным.

# %% [markdown]
# **Сегментация покупателей:**
#
# Распределение по акционным покупкам показывает что клиенты которые покупают товар по акции имеют высокую вероятность перейти в статус "Покупательская активность снизилась". Рассмотрим группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
#
# Пороги значений для разделения покупателей на сегмент "Покупательская активность снизилась":
# * активность в текущем месяце и за 6 месяцев менее 3,5;
# * акционные покупки менее 0,6;
# * просмотриваемые страницы за визит менее 3;
# * неоплаченные заказы за квартал более 6;
# * выручка за предыдущий месяц менее 4500;
# * сумма выручки за текущий и предыдущие месяца менее 8000;
# * кол-во проведенных минут за текущий месяц менее 9;
# * кол-во проведенных минут за предыдущий месяц менее 9.

# %% [markdown]
# **Итоговые рекомендации:**
# * Для профилактики снижения активности рекомендую обратить внимание на неоплаченные товары в корзине, при желании можно настроить целенаправленную рассылку промокодов на данные товары, для поднятия интереса к покупке;
# * Для данного сегмента разработать спец.тайминги для рассылки промокодов. За основу взять среднее время между добавлением в корзину и покупой из корзины. Также, мне кажется, следует учитывать платёжеспособность пользователей и пополнение счёта т.е дни получения заработной платы в периоды с 1-15 по 15-30/31 числа. По итогу должны получиться числа дней оптимальные для рассылки с высокой вероятностью замотивировать к покупке.
# * Я думаю, тот кто в среднем просматривает меньше страниц, скорее всего уже знает что ему нужно и выцеливает где выгоднее купить. Возможно применить систему внутренних бонусов (которые действуют внутри интернет-магазина)за покупки. Также данная система позволит в долгосрочной перспективе привлечь и удержать пользователей;
# * Отказаться от спама/нецелевой рассылки для данного сегмента. Позволит сэкономить деньги и перенаправить их в другое русло см.выше;
